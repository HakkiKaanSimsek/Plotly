# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import plotly.offline as py
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
from plotly import tools
import plotly.figure_factory as ff

df = pd.read_csv('data/flights.csv', low_memory=False)
airlines = pd.read_csv('data/airlines.csv')
df = pd.merge(df,airlines, left_on='AIRLINE', right_on = 'IATA_CODE')
df.insert(loc=5, column='AIRLINE', value=df.AIRLINE_y)
df = df.drop(['AIRLINE_y','IATA_CODE'], axis=1)

airport = pd.read_csv('data/airports.csv')
df = pd.merge(df,airport[['IATA_CODE','AIRPORT','CITY']], left_on='ORIGIN_AIRPORT', right_on = 'IATA_CODE')
df = df.drop(['IATA_CODE'], axis=1)
df = pd.merge(df,airport[['IATA_CODE','AIRPORT','CITY']], left_on='DESTINATION_AIRPORT', right_on = 'IATA_CODE')
df = df.drop(['IATA_CODE'], axis=1)
df.head(2).T
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
#                                                                0  \
# YEAR                                                        2015
# MONTH                                                          1
# DAY                                                            1
# DAY_OF_WEEK                                                    4
# AIRLINE_x                                                     AS
# AIRLINE                                     Alaska Airlines Inc.
# FLIGHT_NUMBER                                                 98
# TAIL_NUMBER                                               N407AS
# ORIGIN_AIRPORT                                               ANC
# DESTINATION_AIRPORT                                          SEA
# SCHEDULED_DEPARTURE                                            5
# DEPARTURE_TIME                                              2354
# DEPARTURE_DELAY                                              -11
# TAXI_OUT                                                      21
# WHEELS_OFF                                                    15
# SCHEDULED_TIME                                               205
# ELAPSED_TIME                                                 194
# AIR_TIME                                                     169
# DISTANCE                                                    1448
# WHEELS_ON                                                    404
# TAXI_IN                                                        4
# SCHEDULED_ARRIVAL                                            430
# ARRIVAL_TIME                                                 408
# ARRIVAL_DELAY                                                -22
# DIVERTED                                                       0
# CANCELLED                                                      0
# CANCELLATION_REASON                                          NaN
# AIR_SYSTEM_DELAY                                             NaN
# SECURITY_DELAY                                               NaN
# AIRLINE_DELAY                                                NaN
# LATE_AIRCRAFT_DELAY                                          NaN
# WEATHER_DELAY                                                NaN
# AIRPORT_x            Ted Stevens Anchorage International Airport
# CITY_x                                                 Anchorage
# AIRPORT_y                   Seattle-Tacoma International Airport
# CITY_y                                                   Seattle
#
#                                                                1
# YEAR                                                        2015
# MONTH                                                          1
# DAY                                                            1
# DAY_OF_WEEK                                                    4
# AIRLINE_x                                                     AS
# AIRLINE                                     Alaska Airlines Inc.
# FLIGHT_NUMBER                                                108
# TAIL_NUMBER                                               N309AS
# ORIGIN_AIRPORT                                               ANC
# DESTINATION_AIRPORT                                          SEA
# SCHEDULED_DEPARTURE                                           45
# DEPARTURE_TIME                                                41
# DEPARTURE_DELAY                                               -4
# TAXI_OUT                                                      17
# WHEELS_OFF                                                    58
# SCHEDULED_TIME                                               204
# ELAPSED_TIME                                                 194
# AIR_TIME                                                     173
# DISTANCE                                                    1448
# WHEELS_ON                                                    451
# TAXI_IN                                                        4
# SCHEDULED_ARRIVAL                                            509
# ARRIVAL_TIME                                                 455
# ARRIVAL_DELAY                                                -14
# DIVERTED                                                       0
# CANCELLED                                                      0
# CANCELLATION_REASON                                          NaN
# AIR_SYSTEM_DELAY                                             NaN
# SECURITY_DELAY                                               NaN
# AIRLINE_DELAY                                                NaN
# LATE_AIRCRAFT_DELAY                                          NaN
# WEATHER_DELAY                                                NaN
# AIRPORT_x            Ted Stevens Anchorage International Airport
# CITY_x                                                 Anchorage
# AIRPORT_y                   Seattle-Tacoma International Airport
# CITY_y                                                   Seattle

# %%
dff = df.groupby('AIRLINE')[['CANCELLED']].mean().sort_values(by='CANCELLED', ascending=False).round(3)

# %%
trace1 = go.Scatter(
    x=dff.index,
    y=dff.CANCELLED
    )
data = [trace1]
py.iplot(data)
# Out:
# <div id="e6f4be24-ab3e-465f-98fe-c6778d72ad21" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e6f4be24-ab3e-465f-98fe-c6778d72ad21", [{"x": ["American Eagle Airlines Inc.", "Atlantic Southeast Airlines", "US Airways Inc.", "Spirit Air Lines", "Skywest Airlines Inc.", "JetBlue Airways", "American Airlines Inc.", "United Air Lines Inc.", "Southwest Airlines Co.", "Virgin America", "Frontier Airlines Inc.", "Delta Air Lines Inc.", "Alaska Airlines Inc.", "Hawaiian Airlines Inc."], "y": [0.054, 0.028, 0.02, 0.018, 0.018, 0.017, 0.016, 0.014, 0.014, 0.009, 0.007, 0.005, 0.004, 0.002], "type": "scatter", "uid": "c1fee34a-bf2b-11e8-ac0a-45f88f22d00e"}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
trace1 = go.Scatter(
    x=dff.index,
    y=dff.CANCELLED
    )

layout = go.Layout(xaxis=dict(tickangle=20),
    title='Şehirlere Göre Uçuşların İptal Edilme Oranları', yaxis = dict(title = '%')
)
data = [trace1]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="a799610c-25bd-4fd6-ba69-4ec3823104cc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             'a799610c-25bd-4fd6-ba69-4ec3823104cc',
#             [{"x": ["American Eagle Airlines Inc.", "Atlantic Southeast Airlines", "US Airways Inc.", "Spirit Air Lines", "Skywest Airlines Inc.", "JetBlue Airways", "American Airlines Inc.", "United Air Lines Inc.", "Southwest Airlines Co.", "Virgin America", "Frontier Airlines Inc.", "Delta Air Lines Inc.", "Alaska Airlines Inc.", "Hawaiian Airlines Inc."], "y": [0.054, 0.028, 0.02, 0.018, 0.018, 0.017, 0.016, 0.014, 0.014, 0.009, 0.007, 0.005, 0.004, 0.002], "type": "scatter", "uid": "c20e3c32-bf2b-11e8-ac0a-45f88f22d00e"}],
#             {"title": "\u015eehirlere G\u00f6re U\u00e7u\u015flar\u0131n \u0130ptal Edilme Oranlar\u0131", "xaxis": {"tickangle": 20}, "yaxis": {"title": "%"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('a799610c-25bd-4fd6-ba69-4ec3823104cc',{});}).then(function(){Plotly.animate('a799610c-25bd-4fd6-ba69-4ec3823104cc');})
#         });</script>

# %%
trace1 = go.Scatter(
    x=dff.index,
    y=dff.CANCELLED,
    mode='markers',
    marker=dict(symbol = 'diamond',
        sizemode = 'diameter',
        size = 20
    )
)
layout = go.Layout(xaxis=dict(tickangle=20),
    title='Şehirlere Göre Uçuşların İptal Edilme Oranları', yaxis = dict(title = '%')
)
data = [trace1]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="81282efc-028c-4ed8-a986-271ef0574b17" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '81282efc-028c-4ed8-a986-271ef0574b17',
#             [{"marker": {"size": 20, "sizemode": "diameter", "symbol": "diamond"}, "mode": "markers", "x": ["American Eagle Airlines Inc.", "Atlantic Southeast Airlines", "US Airways Inc.", "Spirit Air Lines", "Skywest Airlines Inc.", "JetBlue Airways", "American Airlines Inc.", "United Air Lines Inc.", "Southwest Airlines Co.", "Virgin America", "Frontier Airlines Inc.", "Delta Air Lines Inc.", "Alaska Airlines Inc.", "Hawaiian Airlines Inc."], "y": [0.054, 0.028, 0.02, 0.018, 0.018, 0.017, 0.016, 0.014, 0.014, 0.009, 0.007, 0.005, 0.004, 0.002], "type": "scatter", "uid": "c2214a34-bf2b-11e8-ac0a-45f88f22d00e"}],
#             {"title": "\u015eehirlere G\u00f6re U\u00e7u\u015flar\u0131n \u0130ptal Edilme Oranlar\u0131", "xaxis": {"tickangle": 20}, "yaxis": {"title": "%"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('81282efc-028c-4ed8-a986-271ef0574b17',{});}).then(function(){Plotly.animate('81282efc-028c-4ed8-a986-271ef0574b17');})
#         });</script>

# %%
trace1 = go.Scatter(
    x=dff.index,
    y=dff.CANCELLED,
    mode='markers',
    marker=dict(symbol = 'diamond',
        sizemode = 'diameter',
        size = 30,
        color = dff.CANCELLED,
        colorscale='Portland',
        showscale=True
    ),
)
layout = go.Layout(xaxis=dict(tickangle=20),
    title='Şehirlere Göre Uçuşların İptal Edilme Oranları', yaxis = dict(title = '%')
)
data = [trace1]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="7abdbcdd-ec77-4758-982c-72900f051391" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '7abdbcdd-ec77-4758-982c-72900f051391',
#             [{"marker": {"color": [0.054, 0.028, 0.02, 0.018, 0.018, 0.017, 0.016, 0.014, 0.014, 0.009, 0.007, 0.005, 0.004, 0.002], "colorscale": "Portland", "showscale": true, "size": 30, "sizemode": "diameter", "symbol": "diamond"}, "mode": "markers", "x": ["American Eagle Airlines Inc.", "Atlantic Southeast Airlines", "US Airways Inc.", "Spirit Air Lines", "Skywest Airlines Inc.", "JetBlue Airways", "American Airlines Inc.", "United Air Lines Inc.", "Southwest Airlines Co.", "Virgin America", "Frontier Airlines Inc.", "Delta Air Lines Inc.", "Alaska Airlines Inc.", "Hawaiian Airlines Inc."], "y": [0.054, 0.028, 0.02, 0.018, 0.018, 0.017, 0.016, 0.014, 0.014, 0.009, 0.007, 0.005, 0.004, 0.002], "type": "scatter", "uid": "c23a608c-bf2b-11e8-ac0a-45f88f22d00e"}],
#             {"title": "\u015eehirlere G\u00f6re U\u00e7u\u015flar\u0131n \u0130ptal Edilme Oranlar\u0131", "xaxis": {"tickangle": 20}, "yaxis": {"title": "%"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('7abdbcdd-ec77-4758-982c-72900f051391',{});}).then(function(){Plotly.animate('7abdbcdd-ec77-4758-982c-72900f051391');})
#         });</script>

# %%
trace1 = go.Scatter(
    x=dff.index,
    y=dff.CANCELLED,
    mode='markers',
    marker=dict(symbol = 'star-square',
        sizemode = 'diameter',
        size = 30,
        color = dff.CANCELLED,
        colorscale='Portland',
        showscale=True
    )
)
layout = go.Layout(xaxis=dict(tickangle=20),
    title='Şehirlere Göre Uçuşların İptal Edilme Oranları', yaxis = dict(title = '%')
)
data = [trace1]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="5d5b8ad0-e3f7-4dfc-96df-e91f08041e51" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '5d5b8ad0-e3f7-4dfc-96df-e91f08041e51',
#             [{"marker": {"color": [0.054, 0.028, 0.02, 0.018, 0.018, 0.017, 0.016, 0.014, 0.014, 0.009, 0.007, 0.005, 0.004, 0.002], "colorscale": "Portland", "showscale": true, "size": 30, "sizemode": "diameter", "symbol": "star-square"}, "mode": "markers", "x": ["American Eagle Airlines Inc.", "Atlantic Southeast Airlines", "US Airways Inc.", "Spirit Air Lines", "Skywest Airlines Inc.", "JetBlue Airways", "American Airlines Inc.", "United Air Lines Inc.", "Southwest Airlines Co.", "Virgin America", "Frontier Airlines Inc.", "Delta Air Lines Inc.", "Alaska Airlines Inc.", "Hawaiian Airlines Inc."], "y": [0.054, 0.028, 0.02, 0.018, 0.018, 0.017, 0.016, 0.014, 0.014, 0.009, 0.007, 0.005, 0.004, 0.002], "type": "scatter", "uid": "c25693f6-bf2b-11e8-ac0a-45f88f22d00e"}],
#             {"title": "\u015eehirlere G\u00f6re U\u00e7u\u015flar\u0131n \u0130ptal Edilme Oranlar\u0131", "xaxis": {"tickangle": 20}, "yaxis": {"title": "%"}},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('5d5b8ad0-e3f7-4dfc-96df-e91f08041e51',{});}).then(function(){Plotly.animate('5d5b8ad0-e3f7-4dfc-96df-e91f08041e51');})
#         });</script>

# %%
df['Date'] = pd.to_datetime(df[['DAY','MONTH','YEAR']])
df = df[df.MONTH < 9]
df1dm = df.resample('D', on='Date').mean()

# %%
hist_data = [df1dm.ARRIVAL_DELAY]
labels = ['Ortalama Gecikme']

fig = ff.create_distplot(hist_data, labels)
py.iplot(fig)
# Out:
# <div id="93d5d7c8-9e90-404a-b569-3ed8b95db8b6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '93d5d7c8-9e90-404a-b569-3ed8b95db8b6',
#             [{"autobinx": false, "histnorm": "probability density", "legendgroup": "Ortalama Gecikme", "marker": {"color": "rgb(31, 119, 180)"}, "name": "Ortalama Gecikme", "opacity": 0.7, "x": [5.352495543672014, 9.838903743315509, 25.461860465116278, 31.975011015295525, 18.81131019036954, 21.299273998386663, 11.955428646448732, 13.316482498511215, 12.25561145510836, 1.9224748723018619, 10.187042332101262, 18.563997662185855, 3.162599451761717, -0.8171018276762402, 1.6521602414942456, 0.9246451128759927, -5.283255736614566, -0.3105159454134131, -2.200355284862327, -2.175935153810378, 2.291639578728384, -0.056275966259599644, -0.16828885400313973, -0.683511741764169, -0.6371638814386906, 2.082742150734003, -6.712094010119145, -4.753539733080415, -0.8348618090452261, 6.492659053833605, -3.2324993682082384, 10.034090909090908, 17.538126860544995, 8.471012997730554, 7.894626060645925, 12.489839092249504, 0.5851664025356577, -6.25593234255686, 2.906921073012744, 5.127021101671691, -2
Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday','Sunday'],
                   y=fv.index.values, colorscale='Jet')

data=[trace1]
layout = go.Layout(
    title='En Düşük Gecikmeye Sahip Şehirler'
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig)
# Out:
# <div id="746b2a72-6b85-43dd-873b-95941065191e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '746b2a72-6b85-43dd-873b-95941065191e',
#             [{"colorscale": "Jet", "x": ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"], "y": ["Vernal", "Twin Falls", "Elko", "Gillette", "Dillingham", "Lewiston", "Butte", "Moab"], "z": [[-5.4186046511627906, -4.964285714285714, -6.705882352941177, -8.674418604651162, -6.235294117647059, -9.052631578947368, 3.5517241379310347], [2.8, -9.825396825396826, -4.7936507936507935, -5.953846153846154, -5.545454545454546, -11.5, -3.196969696969697], [-5.616822429906542, -4.932038834951456, -4.605769230769231, -3.5045871559633026, -4.685185185185185, -6.813953488372093, -8.790476190476191], [-9.545454545454545, 0.0, -12.272727272727273, -18.545454545454547, -6.090909090909091, 5.090909090909091, -13.727272727272727], [-4.028985507246377, -11.630434782608695, -8.851851851851851, -8.159420289855072, -7.457142857142857, -10.872340425531915, -6.823529411764706], [-13.685714285714285, -13.646153846153846, -13.865671641791044, -11.18840579710145, -6.557142857142857, -11.0, -7.735294117647059], [-21.147058823529413, -17.764705882352942, -17.529411764705884, -20.52777777777778, -20.705882352941178, -21.03030303030303, -23.029411764705884]], "type": "heatmap", "uid": "c8f7b4a6-bf2b-11e8-ac0a-45f88f22d00e"}],
#             {"title": "En D\u00fc\u015f\u00fck Gecikmeye Sahip \u015eehirler"},
#             {"showLink": true, "linkText": "Export to plot.ly"}
#         ).then(function () {return Plotly.addFrames('746b2a72-6b85-43dd-873b-95941065191e',{});}).then(function(){Plotly.animate('746b2a72-6b85-43dd-873b-95941065191e');})
#         });</script>

# %%
df['SPEED'] = 60*df['DISTANCE']/df['AIR_TIME']
dff = df.groupby('AIRLINE').SPEED.mean().to_frame().sort_values(by='SPEED',ascending=False).round(2)

correlation = df[['DAY_OF_WEEK','MONTH','ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
       'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL', 'ARRIVAL_TIME',
       'ARRIVAL_DELAY','SPEED']].fillna(0).corr()
cols = correlation.columns.values
corr  = correlation.values

# %%
trace1 = go.Heatmap(z = corr,
                   x = cols,
                   y = cols,
                   colorscale = "YlOrRd",reversescale = True
                                    ) 

layout = go.Layout(dict(title = "Korelasyon Matrisi",
                        autosize = False,
                        height  = 600,
                        width   = 800,
                        margin  = dict(l = 200),
                        yaxis   = dict(tickfont = dict(size = 8)),
                        xaxis   = dict(tickfont = dict(size = 8))
                       )
                  )
data = [trace1]
fig = go.Figure(data=data,layout=layout)
py.iplot(fig)
# Out:
# <div id="5061d298-ef87-4f65-b054-6b784d8f9f0e" style="height: 600px; width: 800px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             